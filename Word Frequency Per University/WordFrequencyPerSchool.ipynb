# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns
sns.set(style = "whitegrid", 
        color_codes = True,
        font_scale = 1.5)

# %%
# !pip install textblob
from textblob import TextBlob

# %% [markdown]
# ## Cornell Data

# %%
#Load Cornell Data and Filter to necessary Columns
cornell = pd.read_csv('cornelldata.csv')
cornell_data = cornell['Body']
cornell_data.index = cornell['Publish Date']

#Creating new columns for total counts/averages to be used later
afraid = [0]*cornell_data.shape[0]
anxiety = [0]*cornell_data.shape[0]
scared = [0]*cornell_data.shape[0]
lonely = [0]*cornell_data.shape[0]
stressed = [0]*cornell_data.shape[0]
helpw = [0]*cornell_data.shape[0]
failure =  [0]*cornell_data.shape[0]
death = [0]*cornell_data.shape[0]
depressed =  [0]*cornell_data.shape[0]
happy =  [0]*cornell_data.shape[0]
good = [0]*cornell_data.shape[0]

# %%
#Code for accumulating the frequency of each word per month
for i in range(cornell_data.shape[0]):
    words = TextBlob(cornell_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depressed' or word == 'depression' or word == 'depress': depressed[i]= 1
cornellwords = pd.DataFrame({'text':cornell_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                        'Happy': happy,
                        'Good': good,
                        'Depressed': depressed},
                        index=cornell_data.index)
cornellwords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 07:34:08  I always wonder who designed the courses for i...
# 2020-03-01 08:22:54  Freshman fall semester was better than this bs...
# 2020-03-01 08:37:00  We get it you have a micropenis, no need to an...
# 2020-03-01 08:42:32  Like Zeta Theta Zeta Iota. Apparently it's jus...
# 2020-03-01 09:28:34  please help we have a test on wednesday I go t...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 07:34:08       0        0       0       0         0     0        0
# 2020-03-01 08:22:54       0        0       0       0         0     0        0
# 2020-03-01 08:37:00       0        0       0       0         0     0        0
# 2020-03-01 08:42:32       0        0       0       0         0     0        0
# 2020-03-01 09:28:34       0        0       0       0         0     1        0
#
# ...

# %%
#Accumulating the frequencies per month
cornellwords.index = pd.to_datetime(cornellwords.index)
#Samples monthly data for keywords
cornellmonthly = cornellwords.resample('M').sum()
cornellmonthly.drop(cornellmonthly.tail(1).index,inplace=True) #drop unnecessary last row
cornellmonthly['University'] = 'Cornell'

#Converting the results to a csv for Interactive Dashboard
cornellmonthly.to_csv('cornellmonthly.csv')

# %% [markdown]
# ## UCLA Data

# %%
#Loading in UCLA Data and filtering to necessary columns
ucla = pd.read_csv('ucladata.csv')
ucla_data = ucla['Body']
ucla_data.index = ucla['Publish Date']

#Creating new columns for total counts/averages to be used later
afraid = [0]*ucla_data.shape[0]
anxiety = [0]*ucla_data.shape[0]
scared = [0]*ucla_data.shape[0]
lonely = [0]*ucla_data.shape[0]
stressed = [0]*ucla_data.shape[0]
helpw = [0]*ucla_data.shape[0]
failure =  [0]*ucla_data.shape[0]
death = [0]*ucla_data.shape[0]
depressed = [0]*ucla_data.shape[0]
happy =  [0]*ucla_data.shape[0]
good = [0]*ucla_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(ucla_data.shape[0]):
    words = TextBlob(ucla_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depressed' or word == 'depression' or word == 'depress': depressed[i]= 1
uclawords = pd.DataFrame({'text':ucla_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                         'Help': helpw,
                        'Failure': failure,
                         'Death': death,
                          'Happy': happy,
                        'Good': good,
                         'Depressed': depressed},
                        index=ucla_data.index)
uclawords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 09:15:20  This would be for a September move-in! Please ...
# 2020-03-01 09:34:42                   Hey Siri play UCLA by RL Grime 🔥
# 2020-03-01 10:12:35  I got a near perfect score the first time I ra...
# 2020-03-01 10:17:30  I’ve yet to meet a single person who feels hel...
# 2020-03-01 10:29:27           Please 😢 I’m struggling \nWilling to pay
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 09:15:20       0        0       0       0         0     0        0
# 2020-03-01 09:34:42       0        0       0       0         0     0        0
# 2020-03-01 10:12:35       0        0       0       0         0     0        0
# 2020-03-01 10:17:30       0        0       0       0         0     0        0
# 2020-03-01 10:29:27       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
uclawords.index = pd.to_datetime(uclawords.index)
#Samples monthly data for keywords
uclamonthly = uclawords.resample('M').sum()
uclamonthly.drop(uclamonthly.tail(1).index,inplace=True) #drop unnecessary last row
uclamonthly['University'] = 'UCLA'

# %%
#Converting the results to a csv for Interactive Dashboard
uclamonthly.to_csv('uclamonthly.csv')

# %% [markdown]
# ## UCSD Data

# %%
#Loading UC San Diego Data and filtering to necessary columns
ucsd = pd.read_csv('ucsddata.csv')
ucsd_data = ucsd['Body']
ucsd_data.index = ucsd['Publish Date']

#Creating new columns for total counts/averages to be used later
afraid = [0]*ucsd_data.shape[0]
anxiety = [0]*ucsd_data.shape[0]
scared = [0]*ucsd_data.shape[0]
lonely = [0]*ucsd_data.shape[0]
stressed = [0]*ucsd_data.shape[0]
helpw = [0]*ucsd_data.shape[0]
failure =  [0]*ucsd_data.shape[0]
death = [0]*ucsd_data.shape[0]
depressed = [0]*ucsd_data.shape[0]
happy =  [0]*ucsd_data.shape[0]
good = [0]*ucsd_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(ucsd_data.shape[0]):
    words = TextBlob(ucsd_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depressed' or word == 'depression' or word == 'depress': depressed[i] = 1
ucsdwords = pd.DataFrame({'text':ucsd_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                         'Help': helpw,
                        'Failure': failure,
                         'Death': death,
                          'Happy': happy,
                        'Good': good,
                         'Depressed': depressed},
                        index=ucsd_data.index)
ucsdwords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 00:12:07                UC Super Depression.\n\nAm I right?
# 2020-03-01 02:54:10                                          [removed]
# 2020-03-01 02:57:19                                          [removed]
# 2020-03-01 05:44:33  how busy is it? what are the hours like? was i...
# 2020-03-01 09:53:48  I know this is pretty late in the year, but do...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 00:12:07       0        0       0       0         0     0        0
# 2020-03-01 02:54:10       0        0       0       0         0     0        0
# 2020-03-01 02:57:19       0        0       0       0         0     0        0
# 2020-03-01 05:44:33       0        0       0       0         0     0        0
# 2020-03-01 09:53:48       0        0       0       0         0     1        0
#
# ...

# %%
#Accumulating the frequencies per month
ucsdwords.index = pd.to_datetime(ucsdwords.index)
#Samples monthly data for keywords
ucsdmonthly = ucsdwords.resample('M').sum()
ucsdmonthly.drop(ucsdmonthly.tail(1).index,inplace=True) #drop unnecessary last row
ucsdmonthly['University'] = 'UC San Diego'

# %%
#Converting the results to a csv for Interactive Dashboard
ucsdmonthly.to_csv('ucsdmonthly.csv')

# %% [markdown]
# ## Berkeley Data

# %%
#Loading UC Berkeley Data and filtering to necessary columns
berk = pd.read_csv('berkeleydata.csv')
berk_data = berk['Body']
berk_data.index = berk['Publish Date']

#Creating new columns for total counts/averages to be used later
afraid = [0]*berk_data.shape[0]
anxiety = [0]*berk_data.shape[0]
scared = [0]*berk_data.shape[0]
lonely = [0]*berk_data.shape[0]
stressed = [0]*berk_data.shape[0]
helpw = [0]*berk_data.shape[0]
failure =  [0]*berk_data.shape[0]
death = [0]*berk_data.shape[0]
depressed = [0]*berk_data.shape[0]
happy =  [0]*berk_data.shape[0]
good = [0]*berk_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(berk_data.shape[0]):
    words = TextBlob(berk_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depressed' or word == 'depression' or word == 'depress': depressed[i] = 1
berkwords = pd.DataFrame({'text':berk_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                         'Help': helpw,
                        'Failure': failure,
                         'Death': death,
                          'Happy': happy,
                        'Good': good,
                         'Depressed': depressed},
                        index=berk_data.index)
berkwords.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ea1469a786cd> in <module>
#       1 #Code for accumulating the frequency of each word per text
#       2 for i in range(berk_data.shape[0]):
# ----> 3     words = TextBlob(berk_data[i]).words
#       4     for word in words:
#       5         if word == "afraid": afraid[i]=1
#
# /opt/conda/lib/python3.8/site-packages/textblob/blob.py in __init__(self, text, tokenizer, pos_tagger, np_extractor, analyzer, parser, classifier, clean_html)
#     367                 parser=None, classifier=None, clean_html=False):
#     368         if not isinstance(text, basestring):
# --> 369             raise TypeError('The `text` argument passed to `__init__(text)` '
#     370                             'must be a string, not {0}'.format(type(text)))
#     371         if clean_html:
#
# ...

# %%
#Accumulating the frequencies per month
berkwords.index = pd.to_datetime(berkwords.index)
#Samples monthly data for keywords
berkmonthly = berkwords.resample('M').sum()
berkmonthly.drop(berkmonthly.tail(1).index,inplace=True) #drop unnecessary last row
berkmonthly['University'] = 'UC Berkeley'

# %%
#Converting the results to a csv for Interactive Dashboard
berkmonthly.to_csv('berkmonthly.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1eeb1f1c29f9> in <module>
#       1 #Converting the results to a csv for Interactive Dashboard
# ----> 2 berkmonthly.to_csv('berkmonthly.csv')
#
# NameError: name 'berkmonthly' is not defined

# %% [markdown]
# ## Stanford Data

# %%
#Loading Stanford Data and filtering to necessary columns
stanford = pd.read_csv('stanforddata.csv')
stan_data = stanford['Body']
stan_data.index = stanford['Publish Date']


#Creating new columns for total counts/averages to be used later
afraid = [0]*stan_data.shape[0]
anxiety = [0]*stan_data.shape[0]
scared = [0]*stan_data.shape[0]
lonely = [0]*stan_data.shape[0]
stressed = [0]*stan_data.shape[0]
helpw = [0]*stan_data.shape[0]
failure =  [0]*stan_data.shape[0]
death = [0]*stan_data.shape[0]
depressed = [0]*stan_data.shape[0]
happy =  [0]*stan_data.shape[0]
good = [0]*stan_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(stan_data.shape[0]):
    words = TextBlob(stan_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure' : failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depressed' or word == 'depression' or word == 'depress': depressed[i] = 1
stanwords = pd.DataFrame({'text': stan_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                         'Help': helpw,
                        'Failure': failure,
                         'Death': death,
                          'Happy': happy,
                        'Good': good,
                         'Depressed': depressed},
                        index=stan_data.index)
stanwords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 20:32:59  Hi, Need help writing a paper? I am here to he...
# 2020-03-02 03:01:45                               Couldn’t be stanford
# 2020-03-02 19:19:04                                          [removed]
# 2020-03-03 01:48:39        Remember to vote in the primaries tomorrow!
# 2020-03-03 03:00:23  https://apps.apple.com/us/app/campfire-be-your...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 20:32:59       0        0       0       0         0     1        0
# 2020-03-02 03:01:45       0        0       0       0         0     0        0
# 2020-03-02 19:19:04       0        0       0       0         0     0        0
# 2020-03-03 01:48:39       0        0       0       0         0     0        0
# 2020-03-03 03:00:23       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
stanwords.index = pd.to_datetime(stanwords.index)
#Samples monthly data for keywords
stanmonthly = stanwords.resample('M').sum()
stanmonthly.drop(stanmonthly.tail(1).index,inplace=True) #drop unnecessary last row
stanmonthly['University'] = 'Stanford'

# %%
#Converting the results to a csv for Interactive Dashboard
stanmonthly.to_csv('stanfordmonthly.csv')

# %% [markdown]
# ## NYU Data

# %%
#Loading NYU Data and filtering to necessary columns
nyu = pd.read_csv('nyu.csv')
def fillnaf(tbl):
    tbl1 = tbl["Body"].fillna(tbl["Title"])
    tbl["Body"] = tbl1
    return tbl
nyu = fillnaf(nyu)
nyu_data = nyu['Body']
nyu_data.index = nyu['Publish Date']

# %%
#Creating new columns for total counts/averages to be used later
afraid = [0]*nyu_data.shape[0]
anxiety = [0]*nyu_data.shape[0]
scared = [0]*nyu_data.shape[0]
lonely = [0]*nyu_data.shape[0]
stressed = [0]*nyu_data.shape[0]
helpw = [0]*nyu_data.shape[0]
failure =  [0]*nyu_data.shape[0]
death = [0]*nyu_data.shape[0]
depressed = [0]*nyu_data.shape[0]
happy =  [0]*nyu_data.shape[0]
good = [0]*nyu_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(nyu_data.shape[0]):
    words = TextBlob(nyu_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depressed' or word == 'depression' or word == 'depress': depressed[i] = 1
nyuwords = pd.DataFrame({'text': nyu_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                         'Happy': happy,
                        'Good': good,
                        'Depressed': depressed},
                        index=nyu_data.index)
nyuwords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 06:09:59  I am an incoming freshman currently applying f...
# 2020-03-01 08:00:51  I'm (Female) going to be a senior next year an...
# 2020-03-01 08:23:46  do the guards actually check to see how many t...
# 2020-03-01 08:48:07  Hey! Incoming freshman here. I definitely need...
# 2020-03-01 08:50:18  Going to be a sophomore next year and I’m conf...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 06:09:59       0        0       0       0         0     0        0
# 2020-03-01 08:00:51       0        0       0       0         0     0        0
# 2020-03-01 08:23:46       0        0       0       0         0     0        0
# 2020-03-01 08:48:07       0        0       0       0         0     0        0
# 2020-03-01 08:50:18       0        0       0       0         0     1        0
#
# ...

# %%
#Accumulating the frequencies per month
nyuwords.index = pd.to_datetime(nyuwords.index)
#Samples monthly data for keywords
nyumonthly = nyuwords.resample('M').sum()
nyumonthly.drop(nyumonthly.tail(1).index,inplace=True) #drop unnecessary last row
nyumonthly['University'] = 'NYU'

# %%
#Converting the results to a csv for Interactive Dashboard
nyumonthly.to_csv('nyumonthly.csv')

# %% [markdown]
# ## MIT Data

# %%
#Loading MIT Data and filtering to necessary columns
mit = pd.read_csv('mitdata.csv')
mit_data = mit['Body']
mit_data.index = mit['Publish Date']

# %%
#Creating new columns for total counts/averages to be used later
afraid = [0]*mit_data.shape[0]
anxiety = [0]*mit_data.shape[0]
scared = [0]*mit_data.shape[0]
lonely = [0]*mit_data.shape[0]
stressed = [0]*mit_data.shape[0]
helpw = [0]*mit_data.shape[0]
failure =  [0]*mit_data.shape[0]
death = [0]*mit_data.shape[0]
depressed = [0]*mit_data.shape[0]
happy =  [0]*mit_data.shape[0]
good = [0]*mit_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(mit_data.shape[0]):
    words = TextBlob(mit_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word =='suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depression' or word == 'depressed' or word == 'depress': depressed[i] = 1
mitwords = pd.DataFrame({'text': mit_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                         'Happy': happy,
                        'Good': good,
                        'Depressed': depressed},
                        index=mit_data.index)
mitwords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 20:19:30  Friends, how can I see the work program for el...
# 2020-03-02 03:28:16                                      Oh come on...
# 2020-03-02 04:38:42  Is it too late into the semester to get caught...
# 2020-03-02 20:38:43  Ex: if you are an alumni, especially if you wo...
# 2020-03-02 23:17:56  Hi guys! I am planning to apply to MIT and I h...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 20:19:30       0        0       0       0         0     0        0
# 2020-03-02 03:28:16       0        0       0       0         0     0        0
# 2020-03-02 04:38:42       0        0       0       0         0     0        0
# 2020-03-02 20:38:43       0        0       0       0         0     0        0
# 2020-03-02 23:17:56       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
mitwords.index = pd.to_datetime(mitwords.index)
#Samples monthly data for keywords
mitmonthly = mitwords.resample('M').sum()
mitmonthly.drop(mitmonthly.tail(1).index,inplace=True) #drop unnecessary last row
mitmonthly['University'] = 'MIT'

# %%
#Converting the results to a csv for Interactive Dashboard
mitmonthly.to_csv('mitmonthly.csv')

# %% [markdown]
# ## UCD

# %%
#Loading UC Davis Data and filtering to necessary columns
davis = pd.read_csv('ucddata.csv')
davis_data = davis['Body']
davis_data.index = davis['Publish Date']


#Creating new columns for total counts/averages to be used later
afraid = [0]*davis_data.shape[0]
anxiety = [0]*davis_data.shape[0]
scared = [0]*davis_data.shape[0]
lonely = [0]*davis_data.shape[0]
stressed = [0]*davis_data.shape[0]
helpw = [0]*davis_data.shape[0]
failure =  [0]*davis_data.shape[0]
death = [0]*davis_data.shape[0]
depressed = [0] * davis_data.shape[0]
happy =  [0]*davis_data.shape[0]
good = [0]*davis_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(davis_data.shape[0]):
    words = TextBlob(davis_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depression' or word == 'depressed' or word == 'depress': depressed[i] = 1
daviswords = pd.DataFrame({'text': davis_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                           'Happy': happy,
                        'Good': good,
                          'Depressed': depressed},
                        index=davis_data.index)
daviswords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 12:07:50  [https://discord.gg/DUmdMy](https://discord.gg...
# 2020-03-01 17:30:42                                           What do?
# 2020-03-01 18:10:37  Would I be able to change majors right when I ...
# 2020-03-01 20:11:22   Hi, Need help writing a paper? I am here to h...
# 2020-03-01 20:22:48  Im digging a hole on campus and filling it wit...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 12:07:50       0        0       0       0         0     0        0
# 2020-03-01 17:30:42       0        0       0       0         0     0        0
# 2020-03-01 18:10:37       0        0       0       0         0     0        0
# 2020-03-01 20:11:22       0        0       0       0         0     1        0
# 2020-03-01 20:22:48       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
daviswords.index = pd.to_datetime(daviswords.index)
#Samples monthly data for keywords
davismonthly = daviswords.resample('M').sum()
davismonthly.drop(davismonthly.tail(1).index,inplace=True) #drop unnecessary last row
davismonthly['University'] = 'UC Davis'

# %%
#Converting the results to a csv for Interactive Dashboard
davismonthly.to_csv('davismonthly.csv')

# %% [markdown]
# ## UCI

# %%
#Loading UC Irvine Data and filtering to necessary columns
irvine = pd.read_csv('ucidata.csv')
irvine_data = irvine['Body']
irvine_data.index = irvine['Publish Date']


#Creating new columns for total counts/averages to be used later
afraid = [0]*irvine_data.shape[0]
anxiety = [0]*irvine_data.shape[0]
scared = [0]*irvine_data.shape[0]
lonely = [0]*irvine_data.shape[0]
stressed = [0]*irvine_data.shape[0]
helpw = [0]*irvine_data.shape[0]
failure =  [0]*irvine_data.shape[0]
death = [0]*irvine_data.shape[0]
depressed = [0] * irvine_data.shape[0]
happy =  [0]*irvine_data.shape[0]
good = [0]*irvine_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(irvine_data.shape[0]):
    words = TextBlob(irvine_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depressed' or word == 'depression' or word == 'depress': depressed[i] = 1
irvinewords = pd.DataFrame({'text': irvine_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                            'Happy': happy,
                        'Good': good,
                        'Depressed': depressed},
                        index=irvine_data.index)
irvinewords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 10:12:25  so did the ASUCI president really get impeache...
# 2020-03-01 10:45:45  I guess this is more of a rant and r/offmyches...
# 2020-03-01 10:53:20  Hey guys, does anyone know what would happen t...
# 2020-03-01 13:50:50  How hard would this class be if I haven't take...
# 2020-03-01 17:22:23  When I tried to enroll in CS 161 and 162 befor...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 10:12:25       0        0       0       0         0     0        0
# 2020-03-01 10:45:45       0        0       0       0         0     0        0
# 2020-03-01 10:53:20       0        0       0       0         0     0        0
# 2020-03-01 13:50:50       0        0       0       0         0     0        0
# 2020-03-01 17:22:23       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
irvinewords.index = pd.to_datetime(irvinewords.index)
#Samples monthly data for keywords
irvinemonthly = irvinewords.resample('M').sum()
irvinemonthly.drop(irvinemonthly.tail(1).index,inplace=True) #drop unnecessary last row
irvinemonthly['University'] = 'UC Irvine'

# %%
#Converting the results to a csv for Interactive Dashboard
irvinemonthly.to_csv('irvinemonthly.csv')

# %% [markdown]
# ## Harvard Data

# %%
#loading Harvard Data and filtering to necessary columns
harv = pd.read_csv('harvarddata.csv')
def fillnaf(tbl):
    tbl1 = tbl["Body"].fillna(tbl["Title"])
    tbl["Body"] = tbl1
    return tbl
harv = fillnaf(harv)
harv_data = harv['Body']
harv_data.index = harv['Publish Date']


#Creating new columns for total counts/averages to be used later
afraid = [0]*harv_data.shape[0]
anxiety = [0]*harv_data.shape[0]
scared = [0]*harv_data.shape[0]
lonely = [0]*harv_data.shape[0]
stressed = [0]*harv_data.shape[0]
helpw = [0]*harv_data.shape[0]
failure =  [0]*harv_data.shape[0]
death = [0]*harv_data.shape[0]
depressed = [0]*harv_data.shape[0]
happy =  [0]*harv_data.shape[0]
good = [0]*harv_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(harv_data.shape[0]):
    words = TextBlob(harv_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depressed' or word == 'depression' or word == 'depress': depressed[i] = 1
harvwords = pd.DataFrame({'text': harv_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                          'Happy': happy,
                        'Good': good,
                         'Depressed': depressed},
                        index=harv_data.index)
harvwords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 05:37:37  Seems like it's going to be a bad idea to pack...
# 2020-03-01 08:34:03                                          [removed]
# 2020-03-01 17:18:12                                          [removed]
# 2020-03-01 18:52:42  Was wondering what motivated you guys to pick ...
# 2020-03-01 18:57:11              Couldn’t buy his way into Harvard tho
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 05:37:37       0        0       0       0         0     0        0
# 2020-03-01 08:34:03       0        0       0       0         0     0        0
# 2020-03-01 17:18:12       0        0       0       0         0     0        0
# 2020-03-01 18:52:42       0        0       0       0         0     0        0
# 2020-03-01 18:57:11       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
harvwords.index = pd.to_datetime(harvwords.index)
#Samples monthly data for keywords
harvmonthly = harvwords.resample('M').sum()
harvmonthly.drop(harvmonthly.tail(1).index,inplace=True) #drop unnecessary last row
harvmonthly['University'] = 'Harvard'

#Converting the results to a csv for Interactive Dashboard
harvmonthly.to_csv('harvardmonthly.csv')

# %% [markdown]
# ## UC Merced

# %%
#Loading UC Merced Data and filtering to necessary columns
merced = pd.read_csv('merceddata.csv')
merced_data = merced['Body']
merced_data.index = merced['Publish Date']


#Creating new columns for total counts/averages to be used later
afraid = [0]*merced_data.shape[0]
anxiety = [0]*merced_data.shape[0]
scared = [0]*merced_data.shape[0]
lonely = [0]*merced_data.shape[0]
stressed = [0]*merced_data.shape[0]
helpw = [0]*merced_data.shape[0]
failure =  [0]*merced_data.shape[0]
death = [0]*merced_data.shape[0]
depressed = [0] * merced_data.shape[0]
happy =  [0]*merced_data.shape[0]
good = [0]*merced_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(merced_data.shape[0]):
    words = TextBlob(merced_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depression' or word == 'depressed' or word == 'depress': depressed[i] = 1
mercedwords = pd.DataFrame({'text': merced_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                            'Happy': happy,
                        'Good': good,
                          'Depressed': depressed},
                        index=merced_data.index)
mercedwords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 18:50:37  \n\nHey guys,\nI just created a sub for UC stu...
# 2020-03-02 17:30:21        Remember to vote in the primaries tomorrow!
# 2020-03-02 17:30:36     What are you guys wearing for the career fair?
# 2020-03-05 17:56:50  Anyone know how to be accepted into the facebo...
# 2020-03-06 10:07:08  Improve student's understanding of C and data ...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 18:50:37       0        0       0       0         0     0        0
# 2020-03-02 17:30:21       0        0       0       0         0     0        0
# 2020-03-02 17:30:36       0        0       0       0         0     0        0
# 2020-03-05 17:56:50       0        0       0       0         0     0        0
# 2020-03-06 10:07:08       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
mercedwords.index = pd.to_datetime(mercedwords.index)
#Samples monthly data for keywords
mercedmonthly = mercedwords.resample('M').sum()
mercedmonthly.drop(mercedmonthly.tail(1).index,inplace=True) #drop unnecessary last row
mercedmonthly['University'] = 'UC Merced'

# %%
#Converting the results to a csv for Interactive Dashboard
mercedmonthly.to_csv('mercedmonthly.csv')

# %% [markdown]
# ## UC Riverside

# %%
#Loading UC Riverside Data and filtering to necessary columns
riverside = pd.read_csv('ucr.csv')
riverside_data = riverside['Body']
riverside_data.index = riverside['Publish Date']


#Creating new columns for total counts/averages to be used later
afraid = [0]*riverside_data.shape[0]
anxiety = [0]*riverside_data.shape[0]
scared = [0]*riverside_data.shape[0]
lonely = [0]*riverside_data.shape[0]
stressed = [0]*riverside_data.shape[0]
helpw = [0]*riverside_data.shape[0]
failure =  [0]*riverside_data.shape[0]
death = [0]*riverside_data.shape[0]
depressed = [0] * riverside_data.shape[0]
happy =  [0]*riverside_data.shape[0]
good = [0]*riverside_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(riverside_data.shape[0]):
    words = TextBlob(riverside_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depression' or word == 'depressed' or word == 'depress': depressed[i] = 1
riversidewords = pd.DataFrame({'text': riverside_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                               'Happy': happy,
                        'Good': good,
                          'Depressed': depressed},
                        index=riverside_data.index)
riversidewords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 09:16:17  I'd rather give money to a fellow student than...
# 2020-03-01 09:41:22  I have a project for one of my COM classes &am...
# 2020-03-01 09:58:00  March for Bernie! Tomorrow at the Bell Tower 1...
# 2020-03-01 09:59:39  i just need to read chapter 4. So if someone h...
# 2020-03-01 11:47:52                           How do I find this file?
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 09:16:17       0        0       0       0         0     0        0
# 2020-03-01 09:41:22       0        0       0       0         0     1        0
# 2020-03-01 09:58:00       0        0       0       0         0     0        0
# 2020-03-01 09:59:39       0        0       0       0         0     0        0
# 2020-03-01 11:47:52       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
riversidewords.index = pd.to_datetime(riversidewords.index)
#Samples monthly data for keywords
riversidemonthly = riversidewords.resample('M').sum()
riversidemonthly.drop(riversidemonthly.tail(1).index,inplace=True) #drop unnecessary last row
riversidemonthly['University'] = 'UC Riverside'

# %%
#Converting the results to a csv for Interactive Dashboard
riversidemonthly.to_csv('riversidemonthly.csv')

# %% [markdown]
# ## UC Santa Barbara

# %%
#Loading UC Santa Barbara Data and filtering to necessary columns
ucsb = pd.read_csv('ucsbdata.csv')
ucsb_data = ucsb['Body']
ucsb_data.index = ucsb['Publish Date']


#Creating new columns for total counts/averages to be used later
afraid = [0]*ucsb_data.shape[0]
anxiety = [0]*ucsb_data.shape[0]
scared = [0]*ucsb_data.shape[0]
lonely = [0]*ucsb_data.shape[0]
stressed = [0]*ucsb_data.shape[0]
helpw = [0]*ucsb_data.shape[0]
failure =  [0]*ucsb_data.shape[0]
death = [0]*ucsb_data.shape[0]
depressed = [0] * ucsb_data.shape[0]
happy =  [0]*ucsb_data.shape[0]
good = [0]*ucsb_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(ucsb_data.shape[0]):
    words = TextBlob(ucsb_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depression' or word == 'depressed' or word == 'depress': depressed[i] = 1
ucsbwords = pd.DataFrame({'text': ucsb_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                          'Happy': happy,
                        'Good': good,
                          'Depressed': depressed},
                        index=ucsb_data.index)
ucsbwords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 01:11:42  Does anyone know if making an appointment at t...
# 2020-03-01 02:02:15  Is it just me or are most of the problems on t...
# 2020-03-01 02:31:02                       Anyone feel related to this?
# 2020-03-01 10:24:37             Is anywhere in SB/IV/Goleta hiring rn?
# 2020-03-01 11:15:33  People really hate hoprs huh? Found this while...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 01:11:42       0        0       0       0         0     0        0
# 2020-03-01 02:02:15       0        0       0       0         0     0        0
# 2020-03-01 02:31:02       0        0       0       0         0     0        0
# 2020-03-01 10:24:37       0        0       0       0         0     0        0
# 2020-03-01 11:15:33       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
ucsbwords.index = pd.to_datetime(ucsbwords.index)
#Samples monthly data for keywords
ucsbmonthly = ucsbwords.resample('M').sum()
ucsbmonthly.drop(ucsbmonthly.tail(1).index,inplace=True) #drop unnecessary last row
ucsbmonthly['University'] = 'UC Santa Barbara'

# %%
#Converting the results to a csv for Interactive Dashboard
ucsbmonthly.to_csv('ucsbmonthly.csv')

# %% [markdown]
# ## UC Santa Cruz

# %%
#Loading in UC Santa Cruz Data and filtering to necessary columns
ucsc = pd.read_csv('ucscdata.csv')
ucsc_data = ucsc['Body']
ucsc_data.index = ucsc['Publish Date']


#Creating new columns for total counts/averages to be used later
afraid = [0]*ucsc_data.shape[0]
anxiety = [0]*ucsc_data.shape[0]
scared = [0]*ucsc_data.shape[0]
lonely = [0]*ucsc_data.shape[0]
stressed = [0]*ucsc_data.shape[0]
helpw = [0]*ucsc_data.shape[0]
failure =  [0]*ucsc_data.shape[0]
death = [0]*ucsc_data.shape[0]
depressed = [0] * ucsc_data.shape[0]
happy =  [0]*ucsc_data.shape[0]
good = [0]*ucsc_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(ucsc_data.shape[0]):
    words = TextBlob(ucsc_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depression' or word == 'depressed' or word == 'depress': depressed[i] = 1
ucscwords = pd.DataFrame({'text': ucsc_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                          'Happy': happy,
                        'Good': good,
                          'Depressed': depressed},
                        index=ucsc_data.index)
ucscwords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 00:14:47                                       UCSC be like
# 2020-03-01 01:34:35  I'm in a group of 6 current freshman who want ...
# 2020-03-01 03:39:36  If, hypothetically, I wanted to learn python a...
# 2020-03-01 05:23:48  I was walking to porter from crown at 4:30 am ...
# 2020-03-01 06:46:25  What are the odds classes are canceled on Monday?
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 00:14:47       0        0       0       0         0     0        0
# 2020-03-01 01:34:35       0        0       0       0         0     0        0
# 2020-03-01 03:39:36       0        0       0       0         0     0        0
# 2020-03-01 05:23:48       0        0       1       0         0     0        0
# 2020-03-01 06:46:25       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
ucscwords.index = pd.to_datetime(ucscwords.index)
#Samples monthly data for keywords
ucscmonthly = ucscwords.resample('M').sum()
ucscmonthly.drop(ucscmonthly.tail(1).index,inplace=True) #drop unnecessary last row
ucscmonthly['University'] = 'UC Santa Cruz'

# %%
#Converting the results to a csv for Interactive Dashboard
ucscmonthly.to_csv('ucscmonthly.csv')

# %% [markdown]
# ## Yale

# %%
#Loading Yale Data and filtering to necessary columns
yale = pd.read_csv('yaledata.csv')
yale_data = yale['Body']
yale_data.index =  yale['Publish Date']


#Creating new columns for total counts/averages to be used later
afraid = [0]*yale_data.shape[0]
anxiety = [0]*yale_data.shape[0]
scared = [0]*yale_data.shape[0]
lonely = [0]*yale_data.shape[0]
stressed = [0]*yale_data.shape[0]
helpw = [0]*yale_data.shape[0]
failure =  [0]*yale_data.shape[0]
death = [0]*yale_data.shape[0]
depressed = [0] * yale_data.shape[0]
happy =  [0]*yale_data.shape[0]
good = [0]*yale_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(yale_data.shape[0]):
    words = TextBlob(yale_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depression' or word == 'depressed' or word == 'depress': depressed[i] = 1
yalewords = pd.DataFrame({'text': yale_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                          'Happy': happy,
                        'Good': good,
                          'Depressed': depressed},
                         index=yale_data.index)
yalewords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-01 21:47:53                                               Bruh
# 2020-03-02 04:07:08  I want to be a better student, and my dream sc...
# 2020-03-02 16:37:12  My bad if this was made but I have this discor...
# 2020-03-03 14:16:06  Hope this is the correct sub to post, but I ha...
# 2020-03-03 16:14:48  'Ban this technology': students protest US uni...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-01 21:47:53       0        0       0       0         0     0        0
# 2020-03-02 04:07:08       0        0       0       0         0     0        0
# 2020-03-02 16:37:12       0        0       0       0         0     0        0
# 2020-03-03 14:16:06       0        0       0       0         0     0        0
# 2020-03-03 16:14:48       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
yalewords.index = pd.to_datetime(yalewords.index)
#Samples monthly data for keywords
yalemonthly = yalewords.resample('M').sum()
yalemonthly.drop(yalemonthly.tail(1).index,inplace=True) #drop unnecessary last row
yalemonthly['University'] = 'Yale'

# %%
#Converting the results to a csv for Interactive Dashboard
yalemonthly.to_csv('yalemonthly.csv')

# %% [markdown]
# ## Princeton

# %%
#Loading Princeton Data and filtering to necessary columns
princeton = pd.read_csv('princetondata.csv')
princeton_data = princeton['Body']
princeton_data.index = princeton['Publish Date']


#Creating new columns for total counts/averages to be used later
afraid = [0]*princeton_data.shape[0]
anxiety = [0]*princeton_data.shape[0]
scared = [0]*princeton_data.shape[0]
lonely = [0]*princeton_data.shape[0]
stressed = [0]*princeton_data.shape[0]
helpw = [0]*princeton_data.shape[0]
failure =  [0]*princeton_data.shape[0]
death = [0]*princeton_data.shape[0]
depressed = [0] * princeton_data.shape[0]
happy =  [0]*princeton_data.shape[0]
good = [0]*princeton_data.shape[0]

# %%
#Code for accumulating the frequency of each word per text
for i in range(princeton_data.shape[0]):
    words = TextBlob(princeton_data[i]).words
    for word in words:
        if word == "afraid": afraid[i]=1
        if word == "anxiety" or word == 'anxious': anxiety[i]=1
        if word == "scared": scared[i]=1
        if word == "lonely": lonely[i]=1   # as all headlines are in lowercase
        if word == "stressed" or word == "stress": stressed[i]=1 
        if word == "help": helpw[i]=1  
        if word == 'fail' or word == 'failure': failure[i]= 1
        if word == 'death' or word == 'suicide' or word == 'suicidal': death[i] = 1
        if word == 'happy' : happy[i] = 1
        if word == 'good' : good[i] = 1
        if word == 'depression' or word == 'depressed' or word == 'depress': depressed[i] = 1
princetonwords = pd.DataFrame({'text': princeton_data,
                        'Afraid':afraid,
                        'Anxiety':anxiety,
                        'Scared':scared,
                        'Lonely':lonely,
                        'Stressed':stressed,
                        'Help': helpw,
                        'Failure': failure,
                        'Death': death,
                               'Happy': happy,
                        'Good': good,
                          'Depressed': depressed},
                         index=princeton_data.index)
princetonwords.head()
# Out:
#                                                                   text  \
# Publish Date
# 2020-03-02 03:01:02                                             Bruhhh
# 2020-03-04 21:01:15  This is for whichever asshole(s) stole two of ...
# 2020-03-05 23:07:04  Princeton Team and Merck scientists create a n...
# 2020-03-06 12:58:33  Are you serious, guys? Late at night when I ta...
# 2020-03-06 13:00:27  Are you serious, guys? Late at night when I ta...
#
#                      Afraid  Anxiety  Scared  Lonely  Stressed  Help  Failure  \
# Publish Date
# 2020-03-02 03:01:02       0        0       0       0         0     0        0
# 2020-03-04 21:01:15       0        0       0       0         0     0        0
# 2020-03-05 23:07:04       0        0       0       0         0     0        0
# 2020-03-06 12:58:33       0        0       0       0         0     0        0
# 2020-03-06 13:00:27       0        0       0       0         0     0        0
#
# ...

# %%
#Accumulating the frequencies per month
princetonwords.index = pd.to_datetime(princetonwords.index)
#Samples monthly data for keywords
princetonmonthly = princetonwords.resample('M').sum()
princetonmonthly.drop(princetonmonthly.tail(1).index,inplace=True) #drop unnecessary last row
princetonmonthly['University'] = 'Princeton'

# %%
#Converting the results to a csv for Interactive Dashboard
princetonmonthly.to_csv('princetonmonthly.csv')

# %% [markdown]
# ## Combining Universities to One CSV

# %%
#Combining ALL 9 UCs to one csv
berkm = pd.read_csv('berkmonthly.csv')
ucdm = pd.read_csv('davismonthly.csv')
ucim = pd.read_csv('irvinemonthly.csv')
uclam = pd.read_csv('uclamonthly.csv')
ucsdm = pd.read_csv('ucsdmonthly.csv')
ucsc = pd.read_csv('ucscmonthly.csv')
ucsb = pd.read_csv('ucsbmonthly.csv')
ucm = pd.read_csv('mercedmonthly.csv')
ucr = pd.read_csv('riversidemonthly.csv')
frames = [berkm, ucdm, ucim, uclam, ucsdm,ucm, ucr, ucsb, ucsc]
ucuniversity = pd.concat(frames, ignore_index=True)
ucuniversity.to_csv('ucuniversity.csv')

# %%
#Combining ALL East Coast Universities to one csv
nyum = pd.read_csv('nyumonthly.csv')
cornellm = pd.read_csv('cornellmonthly.csv')
mitm = pd.read_csv('mitmonthly.csv')
harvardm = pd.read_csv('harvardmonthly.csv')
princetonm = pd.read_csv('princetonmonthly.csv')
yalem = pd.read_csv('yalemonthly.csv')
frames = [nyum, cornellm, mitm, harvardm,princetonm, yalem]
eastuniversity = pd.concat(frames, ignore_index=True)
eastuniversity.to_csv('eastuniversity.csv')

# %%
#Combining All West Coast Universities to one csv
stanm = pd.read_csv('stanfordmonthly.csv')
frames1 = [berkm, ucdm, ucim, uclam, ucsdm,ucm, ucr, ucsb, ucsc, stanm]
westuniversities = pd.concat(frames1, ignore_index=True)
westuniversities.to_csv('westuniversity.csv')

#Combining all 16 universities to one csv
frames = [stanm, berkm, ucdm, ucim, uclam, ucsdm,ucr, ucm, ucsb, ucsc, nyum, cornellm, mitm, harvardm, yalem, princetonm]
alluniversities = pd.concat(frames, ignore_index=True)
alluniversities.to_csv('alluniversities.csv')
